# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/PaNavar369/Internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# The goal of this lane is to understand which content and search signals are most strongly associated
# with better search visibility. Rather than predicting a simple yes/no outcome, the model would rank pages
# by their expected search performance or priority for optimization. This helps content teams decide which
# pages deserve attention first based on multiple interacting signals such as CTR, content age, average
# position, impressions, and word count.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# The target is a ranking score that represents a page search performance
# Since there is no direct quality label in the dataset, a proxy target can be created using observed outcomes such as search visibility,
# average position, CTR, or trend direction. These labels come from measured search performance rather than manually defined rules.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# The success metric is NDCG (Normalized Discounted Cumulative Gain) because it measures how well the model ranks the most
# important pages near the top of the recommendation list. A higher NDCG score indicates that pages
# with better observed performance are consistently ranked higher, making the recommendations more useful for content prioritization.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd
df = pd.read_csv(
    "https://raw.githubusercontent.com/PaNavar369/Internship/main/data/raw/content_refresh_anonymized.csv"
)
df.head()
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# Each row represents one content page (URL/page record) together with its observed search performance and content attributes.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# A fixed rule such as "update every page older than one year" ignores how multiple factors interact. Search performance depends on combinations of signals including CTR, average ranking position, content age, impressions, clicks, and trend direction. These relationships are often non-linear and vary across pages. A machine learning ranking model can learn these complex patterns from historical data and produce better prioritization than a single threshold or if-statement.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

# %% [markdown]
#  Every section above is filled — markdown thinking AND the code that backs it --yes
#
#  The notebook runs top to bottom with no errors (Runtime → Run all)n--yes
#
#  No client names, URLs, or private queries anywhere --yes
#
#  My claims use careful words: observed, measured, directional, decision-support
#  Committed to my repo under work/notebooks/ — then submit your repo URL on the card. Done --yes
